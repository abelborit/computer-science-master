# %%
import matplotlib.pyplot as plt
import numpy as np

entradaDatos = ["100","1000", "2000", "3000", "4000","5000", "6000", "7000", "8000","9000", "10000", "20000", "30000", "40000", "50000"]
tiempoProcesamientoPython = [0.126609981060, 21.82428001165, 62.14085003137, 183.2173200368, 311.7560799837, 486.3501099705, 681.5701000094, 958.1987799644, 1193.260069942, 1646.823350012, 1928.187919998, 7124.636140012, 16785.25921000, 32140.98073002, 47437.90182001]
tiempoProcesamientoGo = [0.000000000, 0.494940010, 1.958650010, 4.028720020, 6.813090020, 10.64910010, 16.86822030, 21.20322001, 27.08228100, 33.87629010, 42.38623002, 167.3506101, 373.4584401, 672.7258502, 1035.016770]
tiempoProcesamiento = [0.016970, 1.655700, 5.411630, 11.81160, 21.21250, 32.61910, 44.96860, 63.97320, 80.754915, 104.23141, 127.11545, 499.09814, 1116.4115, 1978.6634, 3118.5751]

# Aumentar el tamaño del gráfico
plt.figure(figsize=(12,8))

# Introducir series de datos con color, marcador, etiqueta y estilo
plt.plot(entradaDatos, tiempoProcesamientoPython, label="Python")
plt.plot(entradaDatos, tiempoProcesamientoGo, label="Go")
plt.plot(entradaDatos, tiempoProcesamiento, label="C++")

# Activar leyendas
plt.legend()

# Titulo de la gráfica
plt.title("Tabla Comparativa SELECTION SORT (10 iteraciones)")

# Etiquetado de los eje
plt.xlabel("Cantidad de entrada de datos")
plt.ylabel("Tiempo promedio de procesamiento (milisegundos)")

# Personalizar Eje de Puntaje de 0 a 52000 en incrementos de 2000
plt.yticks(np.arange(0, 52000, 2000))

# Activar cuadrícula
plt.grid(alpha = 0.3)

plt.show()
