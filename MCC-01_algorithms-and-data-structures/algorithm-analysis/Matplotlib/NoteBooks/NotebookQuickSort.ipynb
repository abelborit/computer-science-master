# %%
import matplotlib.pyplot as plt
import numpy as np

entradaDatos = ["100","1000", "2000", "3000", "4000","5000", "6000", "7000", "8000","9000", "10000", "20000", "30000", "40000", "50000"]
tiempoProcesamientoPython = [0.04685001, 0.67782998, 1.43169999, 3.91183998, 4.84377998, 6.46152000, 7.95723999, 8.97102001, 10.2722399, 8.47290002, 11.0587500, 28.8310900, 36.8985099, 43.5867699, 54.3271499]
tiempoProcesamientoGo = [0.000000, 0.464720, 0.602610, 1.073230, 1.265420, 1.694050, 4.598390, 2.551000, 2.075420, 2.830250, 2.955840, 5.702930, 8.255000, 11.61944, 13.76548]
tiempoProcesamiento = [0.079910, 1.148020, 1.854120, 3.110650, 3.530010, 4.680750, 5.289930, 5.995160, 7.492810, 8.306410, 13.69270, 17.39720, 27.60360, 40.43740, 50.62150]

# Aumentar el tamaño del gráfico
plt.figure(figsize=(12,8))

# Introducir series de datos con color, marcador, etiqueta y estilo
plt.plot(entradaDatos, tiempoProcesamientoPython, label="Python")
plt.plot(entradaDatos, tiempoProcesamientoGo, label="Go")
plt.plot(entradaDatos, tiempoProcesamiento, label="C++")

# Activar leyendas
plt.legend()

# Titulo de la gráfica
plt.title("Tabla Comparativa QUICK SORT (10 iteraciones)")

# Etiquetado de los eje
plt.xlabel("Cantidad de entrada de datos")
plt.ylabel("Tiempo promedio de procesamiento (milisegundos)")

# Personalizar Eje de Puntaje de 0 a 62 en incrementos de 2
plt.yticks(np.arange(0, 62, 2))

# Activar cuadrícula
plt.grid(alpha = 0.3)

plt.show()
