# %%
import matplotlib.pyplot as plt
import numpy as np

entradaDatos = ["100","1000", "2000", "3000", "4000","5000", "6000", "7000", "8000","9000", "10000", "20000", "30000", "40000", "50000"]
tiempoProcesamientoPython = [0.09968999624, 6.85737999677, 33.6971200227, 48.8158600091, 102.356639993, 205.870879995, 224.816080021, 407.337369978, 463.472159981, 639.334340012, 768.145850014, 3133.96456001, 6707.64185004, 12568.0394800, 20324.6212799]
tiempoProcesamientoGo = [0.000000000, 0.826706101, 2.727610201, 6.158550102, 11.68364003, 17.17712001, 25.98638001, 32.83727002, 43.07511001, 54.13579002, 63.22702005, 374.1022104, 954.4675301, 1800.399530, 2886.457870]
tiempoProcesamiento = [0.0049100, 0.5218900, 1.8218900, 3.9607600, 11.797200, 16.963400, 22.042600, 27.552800, 34.134210, 41.019610, 53.374720, 206.83610, 459.03430, 808.95120, 1254.6610]

# Aumentar el tamaño del gráfico
plt.figure(figsize=(12,8))

# Introducir series de datos con color, marcador, etiqueta y estilo
plt.plot(entradaDatos, tiempoProcesamientoPython, label="Python")
plt.plot(entradaDatos, tiempoProcesamientoGo, label="Go")
plt.plot(entradaDatos, tiempoProcesamiento, label="C++")

# Activar leyendas
plt.legend()

# Titulo de la gráfica
plt.title("Tabla Comparativa BUBBLE SORT (10 iteraciones)")

# Etiquetado de los eje
plt.xlabel("Cantidad de entrada de datos")
plt.ylabel("Tiempo promedio de procesamiento (milisegundos)")

# Personalizar Eje de Puntaje de 0 a 23000 en incrementos de 1500
plt.yticks(np.arange(0, 23000, 1500))

# Activar cuadrícula
plt.grid(alpha = 0.3)

plt.show()
