# %%
import matplotlib.pyplot as plt
import numpy as np

entradaDatos = ["100","1000", "2000", "3000", "4000","5000", "6000", "7000", "8000","9000", "10000", "20000", "30000", "40000", "50000"]
tiempoProcesamientoPython = [0.099130010, 2.200649976, 2.764629971, 7.101050007, 9.642669999, 10.99956997, 14.79182001, 15.05678002, 16.64215999, 18.01923997, 22.10480999, 38.02304002, 62.77080999, 90.29701001, 115.8760799]
tiempoProcesamientoGo = [0.000000, 0.169101, 0.604000, 0.768830, 0.984660, 1.172470, 1.439510, 1.487160, 1.975560, 2.319490, 2.148190, 3.887100, 5.903180, 7.860120, 10.38625]
tiempoProcesamiento = [0.078730, 0.962090, 1.644030, 2.564250, 3.543940, 5.469300, 7.223770, 6.174310, 8.942220, 10.56892, 12.54333, 21.78842, 28.89253, 37.25581, 48.43261]

# Aumentar el tamaño del gráfico
plt.figure(figsize=(12,8))

# Introducir series de datos con color, marcador, etiqueta y estilo
plt.plot(entradaDatos, tiempoProcesamientoPython, label="Python")
plt.plot(entradaDatos, tiempoProcesamientoGo, label="Go")
plt.plot(entradaDatos, tiempoProcesamiento, label="C++")

# Activar leyendas
plt.legend()

# Titulo de la gráfica
plt.title("Tabla Comparativa MERGE SORT (10 iteraciones)")

# Etiquetado de los eje
plt.xlabel("Cantidad de entrada de datos")
plt.ylabel("Tiempo promedio de procesamiento (milisegundos)")

# Personalizar Eje de Puntaje de 0 a 124 en incrementos de 4
plt.yticks(np.arange(0, 124, 4))

# Activar cuadrícula
plt.grid(alpha = 0.3)

plt.show()
